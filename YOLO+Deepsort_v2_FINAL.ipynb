# %% [markdown]
# <a href="https://colab.research.google.com/github/rattave/GapAcceptanceModel_YOLOv8/blob/main/YOLO%2BDeepsort_v2_FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.136-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.136-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 64.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 114.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.4 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.136 ultralytics-thop-2.0.14

# %%
# !unzip /content/drive/MyDrive/Capstone/Yolo+deepsort/deep_sort.zip
# Out:
# Archive:  /content/drive/MyDrive/Capstone/Yolo+deepsort/deep_sort.zip
#    creating: deep_sort/
#   inflating: deep_sort/.gitignore
#    creating: deep_sort/application_util/
#   inflating: deep_sort/application_util/image_viewer.py
#   inflating: deep_sort/application_util/preprocessing.py
#   inflating: deep_sort/application_util/visualization.py
#  extracting: deep_sort/application_util/__init__.py
#    creating: deep_sort/deep_sort/
#   inflating: deep_sort/deep_sort/detection.py
#   inflating: deep_sort/deep_sort/iou_matching.py
#   inflating: deep_sort/deep_sort/kalman_filter.py
#   inflating: deep_sort/deep_sort/linear_assignment.py
#   inflating: deep_sort/deep_sort/nn_matching.py
#   inflating: deep_sort/deep_sort/track.py
#   inflating: deep_sort/deep_sort/tracker.py
#  extracting: deep_sort/deep_sort/__init__.py
#    creating: deep_sort/deep_sort/__pycache__/
#   inflating: deep_sort/deep_sort/__pycache__/detection.cpython-312.pyc
#   inflating: deep_sort/deep_sort/__pycache__/iou_matching.cpython-312.pyc
#   inflating: deep_sort/deep_sort/__pycache__/kalman_filter.cpython-312.pyc
#   inflating: deep_sort/deep_sort/__pycache__/linear_assignment.cpython-312.pyc
#   inflating: deep_sort/deep_sort/__pycache__/nn_matching.cpython-312.pyc
#   inflating: deep_sort/deep_sort/__pycache__/track.cpython-312.pyc
#   inflating: deep_sort/deep_sort/__pycache__/tracker.cpython-312.pyc
#   inflating: deep_sort/deep_sort/__pycache__/__init__.cpython-312.pyc
#   inflating: deep_sort/deep_sort_app.py
#   inflating: deep_sort/evaluate_motchallenge.py
#   inflating: deep_sort/generate_videos.py
#   inflating: deep_sort/LICENSE
#   inflating: deep_sort/README.md
#   inflating: deep_sort/show_results.py
#    creating: deep_sort/tools/
#   inflating: deep_sort/tools/freeze_model.py
#   inflating: deep_sort/tools/generate_detections.py
#    creating: deep_sort/tools/__pycache__/
#   inflating: deep_sort/tools/__pycache__/generate_detections.cpython-312.pyc

# %%
###객체추적_v3_deepsort2

import cv2
import numpy as np
import pandas as pd
from ultralytics import YOLO

# DeepSORT 관련 모듈
from deep_sort.deep_sort.tracker import Tracker as DeepSortTracker
from deep_sort.tools import generate_detections as gdet
from deep_sort.deep_sort import nn_matching
from deep_sort.deep_sort.detection import Detection
from collections import Counter

print("Imports done.")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# WARNING:tensorflow:From /usr/local/lib/python3.11/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Imports done.

# %%
mars_small128 = "/content/drive/MyDrive/Capstone/Yolo+deepsort/mars-small128.pb"

# %%
### Deepsort 연결을 위한 class 2개 생성성
class Track:
    def __init__(self, track_id, bbox):
        self.track_id = track_id
        self.bbox = bbox


class DeepSortWrapper:
    def __init__(self, model_filename= mars_small128, max_cosine_distance=0.4, nn_budget=None):
        metric = nn_matching.NearestNeighborDistanceMetric("cosine", max_cosine_distance, nn_budget)
        self.tracker = DeepSortTracker(metric)
        self.encoder = gdet.create_box_encoder(model_filename, batch_size=1)
        self.tracks = []

    def update(self, frame, detections):

        # Step 1: If no detections, run a predict-update cycle with an empty list.
        if len(detections) == 0:
            self.tracker.predict()
            self.tracker.update([])
            self._update_tracks()
            return

        # Step 2: Convert [x1, y1, x2, y2] to [x, y, w, h] for Deep SORT
        bboxes = np.array([d[:4] for d in detections])
        scores = [d[4] for d in detections]
        bboxes[:, 2:] = bboxes[:, 2:] - bboxes[:, :2]

        # Step 3: Generate appearance features for each bounding box
        features = self.encoder(frame, bboxes)

        # Step 4: Wrap everything in Deep SORTs Detection objects
        dets = []
        for bbox_id, bbox in enumerate(bboxes):
            dets.append(Detection(bbox, scores[bbox_id], features[bbox_id]))

        # Step 5: Predict and update the tracker
        self.tracker.predict()
        self.tracker.update(dets)
        self._update_tracks()

    def _update_tracks(self):
        active_tracks = []
        for track in self.tracker.tracks:
            if not track.is_confirmed() or track.time_since_update > 1:
                continue
            bbox = track.to_tlbr()  # returns [x1, y1, x2, y2]
            track_id = track.track_id
            active_tracks.append(Track(track_id, bbox))

        self.tracks = active_tracks

# %%
### tensorflow-gpu 연결에는 문제가 없으나 deepsort의 gpu이용에 문제.
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')  # DeepSORT가 GPU를 사용하지 않도록 설정

# %%
### x축 거리 차 +density 추가


import math
import cv2
import os
import numpy as np
import pandas as pd
from collections import Counter

# YOLO 모델 로드
model_weight_path = "/content/drive/MyDrive/Capstone/best_motorcycle_detector_DAY&NIGHT8.pt"
model = YOLO(model_weight_path)
model.to('cuda')  # GPU 사용

# DeepSORT 초기화
### DeepSORTWrapper와 Mars
tracker = DeepSortWrapper(model_filename= mars_small128, max_cosine_distance=0.2, nn_budget=None)
print("YOLO model and Deep SORT wrapper initialized.")

# 전역 변수 정의
log_data = []
interval_data = []
detected_classes = []
object_data = {}
object_directions = {}
pair_code_map = {}  # Pair Code 매핑
pair_code_counter = 1  # Pair Code 생성용
object_class_counts = {}

frame_counter = 0
pixel_to_meter_ratio = None
density_per_frame = {}

# 영역 정의 (YOLO 형식)
right_turn_zone_yolo = (0.399740, 0.538426, 0.067187, 0.152778)
straight_zone_yolo = (0.810417, 0.805093, 0.141667, 0.171296)
interval_zone_yolo = (0.399219, 0.706481, 0.789062, 0.431481)
finish_zone_yolo = (0.044271, 0.858333, 0.081250, 0.211111)
actual_interval_width = 47.0  # 실제 평가 거리 (미터)

# 고유 ID 생성 및 유지
# def get_unique_id(track_id):
#     if track_id not in unique_ids:
#         unique_ids[track_id] = str(uuid.uuid4())[:8]
#     return unique_ids[track_id]

# 픽셀-to-미터 변환 비율 계산
def calculate_pixel_to_meter_ratio(frame_width):
    interval_width_pixels = interval_zone_yolo[2] * frame_width
    if interval_width_pixels < 1:
        print("Error: interval_width_pixels is 0, check interval_zone_yolo values.")
        return 1.0  # 혹은 기본값 설정
    pixel_to_meter_ratio = actual_interval_width / interval_width_pixels

    if pixel_to_meter_ratio < 0.01:
        print(f"[DEBUG] pixel_to_meter_ratio 값이 너무 작아 기본값(0.1)로 설정합니다.")
        pixel_to_meter_ratio = 0.1

    # print(f"[DEBUG] Pixel-to-Meter Ratio : {pixel_to_meter_ratio}")
    return pixel_to_meter_ratio

# YOLO 형식의 좌표를 픽셀 좌표로 변환
def yolo_to_pixel(label, img_width, img_height, max_size=2000):
    # YOLO format: (x_center, y_center, width, height)
    x_center, y_center, width, height = label

    # 상대 좌표를 픽셀 좌표로 변환
    x1 = (x_center - width / 2) * img_width
    x2 = (x_center + width / 2) * img_width
    y1 = (y_center - height / 2) * img_height
    y2 = (y_center + height / 2) * img_height

    # 바운딩 박스 크기가 너무 커지지 않도록 제한
    width_pixels = max(0, min(max_size, x2 - x1))
    height_pixels = max(0, min(max_size, y2 - y1))

    # 좌표 범위 보정
    x1 = max(0, min(x1, img_width - width_pixels))
    x2 = x1 + width_pixels
    y1 = max(0, min(y1, img_height - height_pixels))
    y2 = y1 + height_pixels

    # 디버깅 출력
    #print(f"YOLO Output (x_center, y_center, width, height): {label}")
    #print(f"Converted Pixel BBox: ({x1}, {y1}, {x2}, {y2})")

    return (int(x1), int(y1), int(x2), int(y2))

# BBox가 특정 Zone과 교차 또는 포함되는지 확인
def is_bbox_in_zone(bbox, zone):
    (x1, y1, x2, y2) = bbox
    (z_x1, z_y1, z_x2, z_y2) = zone
    return not (x2 < z_x1 or x1 > z_x2 or y2 < z_y1 or y1 > z_y2)

# BBox를 기준으로 차량의 방향(우회전/직진)을 분류
def classify_direction(bbox, frame_width, frame_height):
    right_turn_zone = yolo_to_pixel(right_turn_zone_yolo, frame_width, frame_height)
    straight_zone = yolo_to_pixel(straight_zone_yolo, frame_width, frame_height)

    if is_bbox_in_zone(bbox, right_turn_zone):
        return "우회전"
    elif is_bbox_in_zone(bbox, straight_zone):
        return "직진"
    return "미정"

def calculate_angle(dx, dy):
    if dx == 0:
        return 90 if dy > 0 else -90  # 위쪽 이동(90도), 아래쪽 이동(-90도)
    return math.degrees(math.atan2(dy, dx))
# import math

# def calculate_angle(dx, dy):
#     """
#     이동 벡터 (dx, dy)를 이용해 각도를 계산하는 함수.
#     :param dx: X축 이동 거리
#     :param dy: Y축 이동 거리
#     :return: 이동 각도 (degree)
#     """
#     angle = math.degrees(math.atan2(dy, dx))  # atan2는 (-180 ~ 180) 범위 반환
#     return angle



def determine_movement_direction(track_id, current_position):
    """
    객체의 이동 벡터를 계산하고, 실제 이동 방향을 분석하여 반환하는 함수.
    - 수평(왼쪽) 이동 → "직진"
    - 아래쪽 이동 → "우회전"
    - 그 외 → "미정"

    :param track_id: 객체의 고유 추적 ID
    :param current_position: 현재 프레임에서의 객체 중심점 (x, y)
    :return: 이동 방향 ("직진", "우회전", "미정")
    """
    if track_id in object_data:
        prev_position = object_data[track_id]["position"]

        # 이동 벡터 계산
        dx = current_position[0] - prev_position[0]  # X축 이동 거리
        dy = current_position[1] - prev_position[1]  # Y축 이동 거리

        # 이동 방향 각도 계산
       # angle = calculate_angle(dx, dy)

        # ✅ 이동 방향 판별
        if dx < 0:  # 왼쪽 방향 (거의 수평 이동)
            direction = "직진"
        elif dy > 0:  # 아래쪽 이동 → 우회전 가능
            direction = "우회전"
        else:
            direction = "미정"  # 방향을 알 수 없는 경우

        # 객체 데이터 업데이트 (현재 위치를 새로운 기준점으로 저장)
        object_data[track_id] = {"position": current_position, "direction": direction}

        return direction
    else:
        # 처음 감지된 객체 → "미정" 상태로 설정
        object_data[track_id] = {"position": current_position, "direction": "미정"}
        return "미정"

# 이동 거리, 속도, 가속도 계산
import numpy as np


def calculate_motion(object_id, current_position, fps, pixel_to_meter_ratio):
    if object_id in object_data:
        prev_data = object_data[object_id]
        prev_pos = prev_data.get("position",current_position)
        prev_distance = prev_data.get("distance",0.0)
        prev_speed = prev_data.get("speed",0.0)

        # 이전 위치가 현재 위치와 동일하면 거리 계산 제외
        #if np.array_equal(prev_pos, current_position):
        #    print(f"[DEBUG] Object {object_id} did not move.")
        #    return 0.0, prev_speed, 0.0


        # 거리 및 속도 계산
        dx = current_position[0]-prev_pos[0]
        dy = current_position[1]-prev_pos[1]
        distance_pixels = np.linalg.norm([dx,dy])

        distance_meters = prev_distance + (distance_pixels * pixel_to_meter_ratio)
        speed = distance_meters * fps
        acceleration = (speed - prev_speed) * fps

        # 가속도가 비정상적으로 클 경우 제한
        if acceleration > 100:
            print(f"[DEBUG] Object {object_id} - Acceleration 너무 큼: {acceleration:.2f}m/s² → 100으로 제한")
            acceleration = 100
                # 이동이 감지되지 않으면 로그를 남기지 않음

        if distance_meters < 0.01:
            return 0.0, prev_speed, 0.0  # 🔹 작은 이동은 무시

        # 디버깅 정보 출력
        #print(f"[DEBUG] Object {object_id} - Distance: {distance_meters:.2f}m, Speed: {speed:.2f}m/s, Accel: {acceleration:.2f}m/s²")

        # 객체 정보 업데이트
        object_data[object_id] = {"position": current_position, "distance": distance_meters, "speed": speed}
        return distance_meters, speed, acceleration

    else:
        # 객체가 처음 등장했을 때 초기화
        object_data[object_id] = {"position": current_position,"distance":0.0, "speed": 0.0}
        #print(f"[DEBUG] Object {object_id} initialized.")
        return 0.0, 0.0, 0.0


# 객체 클래스 변경 함수
def update_object_class(track_id, new_class):
    track_id = str(track_id)

    if track_id not in object_class_counts:
        object_class_counts[track_id] = Counter()

    # 새로운 클래스를 카운트
    object_class_counts[track_id][new_class] += 1

    # 가장 빈도가 높은 클래스를 가져옴
    most_common_class = object_class_counts[track_id].most_common(1)[0][0]
    #print(f"[DEBUG] Object ID {track_id} - Most Common Class: {most_common_class}")
    class_label = "car" if most_common_class == 2 else "motorcycle"

    # 객체의 클래스가 결정되면 모든 프레임에서 해당 클래스를 업데이트
    for obj in log_data:
        if obj["Object ID"] == track_id:
            obj["Class"] = class_label

    # interval_data에도 반영 (추가된 부분)
    for interval in interval_data:
        if interval["Object 1 ID"] == track_id:
            interval["Object 1 Class"] = class_label
        if interval["Object 2 ID"] == track_id:
            interval["Object 2 Class"] = class_label
    return most_common_class

    # 추가로 객체 정보 갱신
    for track in tracker.tracks:
        if track.track_id == track_id:
            track.class_id = most_common_class

    return most_common_class

# Interval 데이터 생성
def update_interval_data(frame_num, log_data, pixel_to_meter_ratio):
    global interval_data, pair_code_map, pair_code_counter

    right_turn_vehicles = [obj for obj in log_data if obj["Direction"] == "우회전"]
    straight_vehicles = [obj for obj in log_data if obj["Direction"] == "직진" or obj["Direction"]=="미정"]

    for obj1 in right_turn_vehicles:
        for obj2 in straight_vehicles:
            if not obj1.get("Object ID") or not obj2.get("Object ID"):
                continue

            if obj1["Class"] in ["bus","truck"] or obj2["Class"] in ["bus","truck"]:
                continue

            # 중심점 거리 계산
            #center1 = ((obj1["BBox"][0] + obj1["BBox"][2]) / 2, (obj1["BBox"][1] + obj1["BBox"][3]) / 2)
            #center2 = ((obj2["BBox"][0] + obj2["BBox"][2]) / 2, (obj2["BBox"][1] + obj2["BBox"][3]) / 2)
            lag_spacing_pixels = abs(obj1["BBox"][0] - obj2["BBox"][0])
            lag_spacing_meters = lag_spacing_pixels * pixel_to_meter_ratio

            # 고유 Pair Code 생성 및 관리
            pair_key = (obj1["Object ID"], obj2["Object ID"])
            if pair_key not in pair_code_map:
                pair_code_map[pair_key] = pair_code_counter
                pair_code_counter += 1

            interval_data.append({
                "Frame": frame_num,
                "Object 1 ID": obj1["Object ID"],
                "Object 2 ID": obj2["Object ID"],
                "Pair Code": pair_code_map[pair_key],
                "Lag Spacing (m)": lag_spacing_meters,
                "Object 1 Speed (m/s)": obj1["Speed (m/s)"],
                "Object 2 Speed (m/s)": obj2["Speed (m/s)"],
                "Object 1 Class": obj1["Class"],
                "Object 2 Class": obj2["Class"],
                "Density": density_per_frame.get(frame_num,0)
            })

# YOLO 결과를 DeepSORT 입력으로 변환
def yolo_to_deepsort(yolo_results, target_classes):
    detections = []
    classes = []
    for det in yolo_results[0].boxes:
        x1, y1, x2, y2 = map(float, det.xyxy[0].cpu().numpy())
        confidence = float(det.conf.cpu().numpy().item())
        class_id = int(det.cls.cpu().numpy())
        if class_id in target_classes:
            detections.append([(x1, y1, x2, y2), confidence])
            classes.append(class_id)

            # 디버깅 로그 추가: YOLO에서 DeepSORT로 전달되는 바운딩 박스 및 신뢰도 출력
            #print(f"YOLO to DeepSORT - BBox: ({x1}, {y1}, {x2}, {y2}), Confidence: {confidence}, Class ID: {class_id}")

    return detections, classes

# 객체 클래스별 색상 반환 함수
def get_class_color(class_id):
    if class_id == 2:  # car
        return (0, 255, 0)  # 초록 (BGR)
    else:
        return (255, 0, 0)  # 파랑 (BGR)

# 수정된 메인 루프

if __name__ == "__main__":
    target_classes = [2, 3]  # car(2), motorcycle(3)

    video_path = "/content/drive/MyDrive/Capstone/02.24 VIDEO/0224_DAY/0224_1330-1400_filtered.mp4"
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
      print(f"Error: Unable to open video file {video_path}")

    fps = int(cap.get(cv2.CAP_PROP_FPS))

    if fps <= 0 or fps > 60:
      #print(f"[DEBUG] FPS 값이 비정상적({fps}), 기본값(30)으로 설정합니다.")
      fps = 30

    #print(f"[DEBUG] FPS: {fps}")

    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    if frame_width == 0 or frame_height == 0:
      print("Error: Invalid video frame dimensions")

    pixel_to_meter_ratio = calculate_pixel_to_meter_ratio(frame_width)

    output_directory = "/content/drive/MyDrive/Capstone/Results/02.24 1200-1400/Log video"
    import os
    output_video_path = os.path.join(output_directory, '02.24 1330-1400_processed_video2.avi')
    video_writer = cv2.VideoWriter(output_video_path, cv2.VideoWriter_fourcc(*'MJPG'), fps, (frame_width, frame_height))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame_counter += 1

        # YOLO 객체 검출
        results = model(frame, conf=0.3,show_conf=False)

        valid_classes = {2:"car",3:"motorcycle"}
        class_counts = {"car":0,"motorcycle":0}

        # YOLO 결과를 DeepSORT로 변환
        detected_classes.clear()
        all_detections = []

        for r in results:
            for box in r.boxes.data.tolist():
              x1, y1, x2, y2, score, class_id = box
              if score >= 0.5:
                class_name = valid_classes[int(class_id)]
                class_counts[class_name] = class_counts.get(class_name, 0) + 1

                bbox = (int(x1), int(y1), int(x2), int(y2))
                if is_bbox_in_zone(bbox, yolo_to_pixel(interval_zone_yolo, frame_width, frame_height)):
                    all_detections.append([int(x1),int(y1),int(x2),int(y2),float(score)])
                    detected_classes.append(int(class_id))

                if class_id in [2,3,5,7]:
                    density_per_frame[frame_counter] = density_per_frame.get(frame_counter, 0) + 1

        # Ensure detected_classes and tracker.tracks have the same length
        if len(all_detections) != len(detected_classes):
            print(f"Warning: Mismatch between detections ({len(all_detections)}) and detected classes ({len(detected_classes)})")

        # DeepSORTWrapper로 추적
        tracker.update(frame, all_detections)
        if not detected_classes:
            print("Warning: No detected classes were found, skipping classification.")

        current_log_data = []
        for track, detected_class_id in zip(tracker.tracks,detected_classes):
            track_id = track.track_id
            x1, y1, x2, y2 = track.bbox

            # DeepSORT에서 제공하는 track_id를 사용하여 class_id를 가져옴
            #class_id = update_object_class(track_id, 2)  # 기본값 2(car)로 설정

            # 디버깅: 클래스 ID와 색상 확인
            #print(f"Track ID: {track_id}, Updated Class ID: {class_id}")

            updated_class_id = update_object_class(track_id, detected_class_id)

            color = get_class_color(updated_class_id)  # 🔹 color 변수 정의 추가

            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), color, 2)

            if f"ID {track_id}" not in log_data:
                label = "car" if updated_class_id == 2 else "motorcycle"
                direction = object_directions.get(track_id, "미정")

                cv2.putText(frame, f"{label} ID {track_id}",
                            (int(x1), int(y1) - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)


            # 바운딩 박스 x좌표가 음수인 경우, 추적 중단
            if x1 < 0 or y1 < 0 or x2 < 0 or y2 < 0:
                continue

            current_position = ((x1 + x2) // 2, (y1 + y2) // 2)
            #print(f"[DEBUG] Frame {frame_counter} - Object {track_id} Previous Position: {object_data.get(track_id, {}).get('position', 'N/A')} -> Current Position: {current_position}")

            #unique_id = get_unique_id(track_id)



            # 이동 거리, 속도, 가속도 계산
            distance, speed, acceleration = calculate_motion(track_id, current_position, fps, pixel_to_meter_ratio)

            # 이동 벡터를 기반으로 실제 이동 방향 결정
            direction = determine_movement_direction(track_id, current_position)

            bbox = (int(x1), int(y1), int(x2), int(y2))

            # 방향 분류
            direction = object_directions.get(track_id, "미정")
            if direction == "미정":
                direction = classify_direction(bbox, frame_width, frame_height)
                object_directions[track_id] = direction

            # 로그 데이터 기록
            bbox = (int(x1), int(y1), int(x2), int(y2))

            #if not any(obj["Object ID"] == track_id for obj in log_data):
            if is_bbox_in_zone(bbox, yolo_to_pixel(interval_zone_yolo, frame_width, frame_height)):
                direction = classify_direction(bbox, frame_width, frame_height)
                updated_class_id = update_object_class(track_id, detected_class_id)

                obj_data = {
                    "Frame": frame_counter,
                    "Object ID": track_id,
                    "Class": "car" if updated_class_id == 2 else "motorcycle" ,
                    "Distance (m)": distance,
                    "Speed (m/s)": speed,
                    "Acceleration (m/s^2)": acceleration,
                    "Direction": direction,
                    "BBox": (x1, y1, x2, y2),
                    "Density" : density_per_frame.get(frame_counter,0)
                }
            log_data.append(obj_data)
            current_log_data.append(obj_data)

            # 화면 표시
            label = "car" if updated_class_id == 2 else "motorcycle"
            color = get_class_color(updated_class_id)
#            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, f"{label} ID {track_id}", (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5,color, 2)

        # Interval 데이터 업데이트
        update_interval_data(frame_counter, current_log_data, pixel_to_meter_ratio)

        if not video_writer.isOpened():
            print("Error: VideoWriter failed to open.")

        if frame is None:
            print(f"Error: Empty frame at {frame_counter}")




        # 비디오 저장
        video_writer.write(frame)
        # 객체 ID 및 바운딩 박스 정보 로그 출력
        #print(f"Object ID: {unique_id}, BBox: ({x1}, {y1}, {x2}, {y2}), Direction: {direction}")


    # 데이터 저장
    log_data_path = "/content/drive/MyDrive/Capstone/Results/02.24 1200-1400/Log data/1330-1400_log.csv"
    interval_data_path = "/content/drive/MyDrive/Capstone/Results/02.24 1200-1400/Interval data/1330-1400_interval.csv"
    pd.DataFrame(log_data).to_csv(log_data_path, index=False)
    pd.DataFrame(interval_data).to_csv(interval_data_path, index=False)


    print(f"Log data saved to: {log_data_path}")
    print(f"Interval data saved to: {interval_data_path}")

    cap.release()
    video_writer.release()
# Out:
# Streaming output truncated to the last 5000 lines.
# [DEBUG] Object 106 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.6ms
# Speed: 2.3ms preprocess, 11.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.3ms
# Speed: 4.0ms preprocess, 11.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 337.66m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.8ms
# Speed: 2.6ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 337.66m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 17.0ms
# Speed: 4.0ms preprocess, 17.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 10.9ms
# Speed: 1.9ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.0ms
# Speed: 8.6ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 15.0ms
# Speed: 2.2ms preprocess, 15.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 337.66m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 151.00m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 151.00m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 12.2ms
# Speed: 2.3ms preprocess, 12.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 177.69m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 12.3ms
# Speed: 3.4ms preprocess, 12.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 187.30m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.0ms
# Speed: 2.6ms preprocess, 11.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 187.30m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.1ms
# Speed: 2.1ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 337.66m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 151.00m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.9ms
# Speed: 2.4ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.2ms
# Speed: 2.3ms preprocess, 11.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.3ms
# Speed: 2.2ms preprocess, 11.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 462.59m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.4ms
# Speed: 3.2ms preprocess, 11.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 337.66m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 187.30m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 376.93m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.5ms
# Speed: 2.4ms preprocess, 11.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.8ms
# Speed: 2.4ms preprocess, 11.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 151.00m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 14.3ms
# Speed: 2.4ms preprocess, 14.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 151.00m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 15.7ms
# Speed: 2.4ms preprocess, 15.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 151.00m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 376.93m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 10.9ms
# Speed: 3.6ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 151.00m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 14.1ms
# Speed: 2.4ms preprocess, 14.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 151.00m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.1ms
# Speed: 2.3ms preprocess, 11.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 187.30m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.8ms
# Speed: 3.5ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 376.93m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 118.46m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.8ms
# Speed: 2.5ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 420.90m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 13.6ms
# Speed: 3.8ms preprocess, 13.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 376.93m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 151.00m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 10.9ms
# Speed: 8.3ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 151.00m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.7ms
# Speed: 2.8ms preprocess, 11.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 118.46m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.0ms
# Speed: 2.3ms preprocess, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 151.00m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 17.4ms
# Speed: 2.5ms preprocess, 17.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 418.81m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 18.1ms
# Speed: 2.2ms preprocess, 18.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 14.4ms
# Speed: 2.6ms preprocess, 14.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 337.66m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 15.6ms
# Speed: 4.6ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 376.93m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 12.2ms
# Speed: 3.2ms preprocess, 12.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 379.25m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.1ms
# Speed: 2.8ms preprocess, 11.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 304.90m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 118.46m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.0ms
# Speed: 2.6ms preprocess, 11.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 376.93m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 118.46m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 17.3ms
# Speed: 3.0ms preprocess, 17.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 379.25m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 17.8ms
# Speed: 2.3ms preprocess, 17.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 376.93m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 14.2ms
# Speed: 2.3ms preprocess, 14.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 13.3ms
# Speed: 2.6ms preprocess, 13.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 106 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
# [DEBUG] Object 107 - Acceleration 너무 큼: 118.46m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 16.5ms
# Speed: 2.4ms preprocess, 16.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 107 - Acceleration 너무 큼: 118.46m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 14.5ms
# Speed: 5.6ms preprocess, 14.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 107 - Acceleration 너무 큼: 151.00m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 17.9ms
# Speed: 2.3ms preprocess, 17.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 107 - Acceleration 너무 큼: 151.00m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.8ms
# Speed: 2.3ms preprocess, 11.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 15.8ms
# Speed: 2.3ms preprocess, 15.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 16.2ms
# Speed: 2.9ms preprocess, 16.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 14.3ms
# Speed: 2.7ms preprocess, 14.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 14.0ms
# Speed: 2.5ms preprocess, 14.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 13.0ms
# Speed: 4.8ms preprocess, 13.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 107 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 107 - Acceleration 너무 큼: 118.46m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.1ms
# Speed: 2.6ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 13.0ms
# Speed: 2.3ms preprocess, 13.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 12.2ms
# Speed: 2.3ms preprocess, 12.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 107 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 13.8ms
# Speed: 2.4ms preprocess, 13.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 107 - Acceleration 너무 큼: 118.46m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.8ms
# Speed: 2.3ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 11.5ms
# Speed: 4.7ms preprocess, 11.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 12.0ms
# Speed: 3.1ms preprocess, 12.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 11.4ms
# Speed: 2.5ms preprocess, 11.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 10.9ms
# Speed: 3.5ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 107 - Acceleration 너무 큼: 118.46m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 12.3ms
# Speed: 3.1ms preprocess, 12.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 13.3ms
# Speed: 2.9ms preprocess, 13.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 11.7ms
# Speed: 2.6ms preprocess, 11.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 11.2ms
# Speed: 3.0ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 11.3ms
# Speed: 2.2ms preprocess, 11.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 11.2ms
# Speed: 2.2ms preprocess, 11.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 15.2ms
# Speed: 7.0ms preprocess, 15.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 12.7ms
# Speed: 2.6ms preprocess, 12.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 11.9ms
# Speed: 2.6ms preprocess, 11.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 107 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.2ms
# Speed: 2.7ms preprocess, 11.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 107 - Acceleration 너무 큼: 177.69m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 13.1ms
# Speed: 2.3ms preprocess, 13.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 11.3ms
# Speed: 2.5ms preprocess, 11.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 107 - Acceleration 너무 큼: 151.00m/s² → 100으로 제한
# [DEBUG] Object 110 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.1ms
# Speed: 2.2ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 11.0ms
# Speed: 5.1ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 11.0ms
# Speed: 2.3ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 13.9ms
# Speed: 2.4ms preprocess, 13.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 125.64m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 12.0ms
# Speed: 2.4ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 16.3ms
# Speed: 2.4ms preprocess, 16.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 125.64m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.6ms
# Speed: 2.8ms preprocess, 11.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.7ms
# Speed: 2.2ms preprocess, 11.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.9ms
# Speed: 4.9ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 125.64m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.3ms
# Speed: 2.4ms preprocess, 11.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 125.64m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.3ms
# Speed: 2.1ms preprocess, 11.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 13.8ms
# Speed: 3.7ms preprocess, 13.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.1ms
# Speed: 2.7ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 125.64m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 13.5ms
# Speed: 2.4ms preprocess, 13.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.1ms
# Speed: 2.4ms preprocess, 11.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 125.64m/s² → 100으로 제한
#
# 0: 384x640 7 cars, 17.6ms
# Speed: 2.5ms preprocess, 17.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 125.64m/s² → 100으로 제한
#
# 0: 384x640 7 cars, 11.8ms
# Speed: 2.4ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 7 cars, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 7 cars, 11.0ms
# Speed: 2.2ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 125.64m/s² → 100으로 제한
#
# 0: 384x640 7 cars, 12.0ms
# Speed: 2.4ms preprocess, 12.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 7 cars, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 7 cars, 11.3ms
# Speed: 2.4ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 125.64m/s² → 100으로 제한
#
# 0: 384x640 7 cars, 11.2ms
# Speed: 2.6ms preprocess, 11.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 7 cars, 11.6ms
# Speed: 2.4ms preprocess, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 125.64m/s² → 100으로 제한
#
# 0: 384x640 7 cars, 12.0ms
# Speed: 2.5ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 12.0ms
# Speed: 2.3ms preprocess, 12.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 18.0ms
# Speed: 4.3ms preprocess, 18.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 13.5ms
# Speed: 2.3ms preprocess, 13.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.7ms
# Speed: 3.1ms preprocess, 11.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.5ms
# Speed: 2.5ms preprocess, 11.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 125.64m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 15.6ms
# Speed: 2.6ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 125.64m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 13.9ms
# Speed: 2.4ms preprocess, 13.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.0ms
# Speed: 2.6ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.6ms
# Speed: 2.5ms preprocess, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.2ms
# Speed: 2.9ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.6ms
# Speed: 2.5ms preprocess, 11.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 10.9ms
# Speed: 6.5ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 12.1ms
# Speed: 2.6ms preprocess, 12.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.4ms
# Speed: 2.4ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.8ms
# Speed: 2.7ms preprocess, 11.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 125.64m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.5ms
# Speed: 2.3ms preprocess, 11.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 13.9ms
# Speed: 2.4ms preprocess, 13.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.1ms
# Speed: 2.4ms preprocess, 11.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 17.2ms
# Speed: 2.6ms preprocess, 17.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 125.64m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 12.1ms
# Speed: 3.0ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.0ms
# Speed: 2.2ms preprocess, 11.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 118.46m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.3ms
# Speed: 4.9ms preprocess, 11.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.9ms
# Speed: 2.4ms preprocess, 11.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.2ms
# Speed: 2.7ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.1ms
# Speed: 2.8ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 12.7ms
# Speed: 2.5ms preprocess, 12.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 12.5ms
# Speed: 2.4ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 12.6ms
# Speed: 2.2ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.4ms
# Speed: 2.8ms preprocess, 11.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 12.3ms
# Speed: 2.5ms preprocess, 12.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 13.3ms
# Speed: 2.3ms preprocess, 13.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 16.6ms
# Speed: 2.4ms preprocess, 16.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 10.9ms
# Speed: 3.2ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 13.5ms
# Speed: 5.9ms preprocess, 13.5ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 15.7ms
# Speed: 2.2ms preprocess, 15.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 15.3ms
# Speed: 2.8ms preprocess, 15.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.4ms
# Speed: 6.8ms preprocess, 11.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.8ms
# Speed: 4.1ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 14.4ms
# Speed: 2.3ms preprocess, 14.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 13.0ms
# Speed: 2.3ms preprocess, 13.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 14.8ms
# Speed: 6.5ms preprocess, 14.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.2ms
# Speed: 2.6ms preprocess, 11.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 13.2ms
# Speed: 2.4ms preprocess, 13.2ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 14.7ms
# Speed: 2.6ms preprocess, 14.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 12.5ms
# Speed: 2.2ms preprocess, 12.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 13.9ms
# Speed: 4.1ms preprocess, 13.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 15.8ms
# Speed: 2.6ms preprocess, 15.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.0ms
# Speed: 4.1ms preprocess, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.0ms
# Speed: 2.2ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 7 cars, 11.4ms
# Speed: 2.5ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 379.25m/s² → 100으로 제한
#
# 0: 384x640 7 cars, 11.5ms
# Speed: 2.7ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
#
# 0: 384x640 7 cars, 20.0ms
# Speed: 2.3ms preprocess, 20.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 13.6ms
# Speed: 2.6ms preprocess, 13.6ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 14.2ms
# Speed: 2.5ms preprocess, 14.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 15.8ms
# Speed: 2.4ms preprocess, 15.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 12.4ms
# Speed: 2.5ms preprocess, 12.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.0ms
# Speed: 3.3ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.5ms
# Speed: 6.4ms preprocess, 11.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 10.9ms
# Speed: 7.2ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.3ms
# Speed: 2.4ms preprocess, 11.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 15.8ms
# Speed: 2.4ms preprocess, 15.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 12.1ms
# Speed: 2.5ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.4ms
# Speed: 2.5ms preprocess, 11.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 15.1ms
# Speed: 2.4ms preprocess, 15.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 22.1ms
# Speed: 2.7ms preprocess, 22.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 17.5ms
# Speed: 2.4ms preprocess, 17.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.0ms
# Speed: 2.8ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 10.9ms
# Speed: 2.6ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 15.0ms
# Speed: 2.4ms preprocess, 15.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
#
# 0: 384x640 8 cars, 11.5ms
# Speed: 3.7ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.0ms
# Speed: 2.2ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.0ms
# Speed: 4.1ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.1ms
# Speed: 4.6ms preprocess, 11.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.1ms
# Speed: 2.8ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 14.8ms
# Speed: 2.4ms preprocess, 14.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.0ms
# Speed: 2.2ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.3ms
# Speed: 2.4ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 14.0ms
# Speed: 4.7ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 18.4ms
# Speed: 2.6ms preprocess, 18.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 12.0ms
# Speed: 2.5ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.1ms
# Speed: 2.2ms preprocess, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 10.9ms
# Speed: 12.0ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.5ms
# Speed: 2.3ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.0ms
# Speed: 8.0ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 14.6ms
# Speed: 3.2ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 10.9ms
# Speed: 4.1ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 12.1ms
# Speed: 2.5ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.0ms
# Speed: 8.7ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 337.66m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 293.17m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.0ms
# Speed: 2.9ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 304.90m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.2ms
# Speed: 2.5ms preprocess, 11.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 125.64m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.1ms
# Speed: 2.5ms preprocess, 11.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 12.3ms
# Speed: 2.8ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.8ms
# Speed: 2.4ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 12.3ms
# Speed: 2.2ms preprocess, 12.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.9ms
# Speed: 2.4ms preprocess, 11.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 337.66m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.1ms
# Speed: 6.6ms preprocess, 11.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 427.11m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.0ms
# Speed: 9.4ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.3ms
# Speed: 5.6ms preprocess, 11.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.1ms
# Speed: 2.5ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.0ms
# Speed: 3.5ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
#
# 0: 384x640 9 cars, 11.5ms
# Speed: 2.5ms preprocess, 11.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 251.29m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.4ms
# Speed: 2.9ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 296.14m/s² → 100으로 제한
#
# 0: 384x640 11 cars, 11.2ms
# Speed: 2.4ms preprocess, 11.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 335.05m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 110 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
# [DEBUG] Object 111 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
#
# 0: 384x640 10 cars, 11.4ms
# ...
# [DEBUG] Object 135 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 15.5ms
# Speed: 2.5ms preprocess, 15.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 17.6ms
# Speed: 2.6ms preprocess, 17.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 15.3ms
# Speed: 2.5ms preprocess, 15.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 187.30m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.3ms
# Speed: 3.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.0ms
# Speed: 2.2ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 187.30m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.2ms
# Speed: 2.3ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 225.54m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.1ms
# Speed: 2.3ms preprocess, 11.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 12.6ms
# Speed: 4.1ms preprocess, 12.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 23.5ms
# Speed: 2.5ms preprocess, 23.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.2ms
# Speed: 2.6ms preprocess, 11.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 187.30m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.1ms
# Speed: 6.6ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.1ms
# Speed: 2.7ms preprocess, 11.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.9ms
# Speed: 2.5ms preprocess, 11.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 187.30m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.4ms
# Speed: 2.4ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 225.54m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.1ms
# Speed: 2.4ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.3ms
# Speed: 2.4ms preprocess, 11.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 12.9ms
# Speed: 2.5ms preprocess, 12.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.2ms
# Speed: 2.3ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.0ms
# Speed: 2.3ms preprocess, 11.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.1ms
# Speed: 2.4ms preprocess, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 187.30m/s² → 100으로 제한
#
# 0: 384x640 2 cars, 1 motorcycle, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 2 cars, 1 motorcycle, 11.1ms
# Speed: 2.2ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 254.75m/s² → 100으로 제한
#
# 0: 384x640 2 cars, 1 motorcycle, 26.3ms
# Speed: 4.4ms preprocess, 26.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 2 cars, 1 motorcycle, 15.5ms
# Speed: 4.5ms preprocess, 15.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 15.6ms
# Speed: 2.7ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.9ms
# Speed: 3.4ms preprocess, 11.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.5ms
# Speed: 6.6ms preprocess, 11.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 187.30m/s² → 100으로 제한
#
# 0: 384x640 2 cars, 1 motorcycle, 12.4ms
# Speed: 2.3ms preprocess, 12.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 125.64m/s² → 100으로 제한
#
# 0: 384x640 2 cars, 1 motorcycle, 14.8ms
# Speed: 4.4ms preprocess, 14.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.1ms
# Speed: 2.2ms preprocess, 11.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 125.64m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 24.5ms
# Speed: 2.7ms preprocess, 24.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 2 cars, 1 motorcycle, 11.2ms
# Speed: 8.4ms preprocess, 11.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 187.30m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.7ms
# Speed: 3.0ms preprocess, 11.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 14.9ms
# Speed: 2.5ms preprocess, 14.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.4ms
# Speed: 2.5ms preprocess, 11.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 213.55m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 12.6ms
# Speed: 2.5ms preprocess, 12.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.0ms
# Speed: 2.7ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.2ms
# Speed: 2.9ms preprocess, 11.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.3ms
# Speed: 2.5ms preprocess, 11.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 13.3ms
# Speed: 5.1ms preprocess, 13.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 125.64m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.5ms
# Speed: 2.4ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.4ms
# Speed: 2.8ms preprocess, 11.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.4ms
# Speed: 8.5ms preprocess, 11.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 125.64m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 11.9ms
# Speed: 2.5ms preprocess, 11.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 13.5ms
# Speed: 2.4ms preprocess, 13.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 12.8ms
# Speed: 2.8ms preprocess, 12.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 209.41m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 12.6ms
# Speed: 2.9ms preprocess, 12.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 172.68m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 1 motorcycle, 13.1ms
# Speed: 2.7ms preprocess, 13.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 167.52m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 2 motorcycles, 14.0ms
# Speed: 3.7ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 187.30m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 2 motorcycles, 11.1ms
# Speed: 2.3ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [DEBUG] Object 135 - Acceleration 너무 큼: 132.44m/s² → 100으로 제한
#
# 0: 384x640 3 cars, 2 motorcycles, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 motorcycle, 11.1ms
# Speed: 2.5ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 motorcycles, 11.0ms
# Speed: 2.7ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 motorcycle, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 motorcycle, 11.9ms
# Speed: 2.7ms preprocess, 11.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 motorcycles, 11.5ms
# Speed: 2.4ms preprocess, 11.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 motorcycle, 11.2ms
# Speed: 2.6ms preprocess, 11.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 motorcycle, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 motorcycle, 11.1ms
# Speed: 2.3ms preprocess, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 11.0ms
# Speed: 5.9ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 11.0ms
# Speed: 3.7ms preprocess, 11.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 motorcycle, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 motorcycle, 11.9ms
# Speed: 2.7ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.6ms
# Speed: 2.4ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 10.9ms
# Speed: 3.3ms preprocess, 10.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.9ms
# Speed: 2.6ms preprocess, 15.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.5ms
# Speed: 2.8ms preprocess, 13.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.6ms
# Speed: 5.9ms preprocess, 11.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.0ms
# Speed: 2.6ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.3ms
# Speed: 2.4ms preprocess, 11.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.6ms
# Speed: 4.0ms preprocess, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 motorcycle, 11.9ms
# Speed: 2.2ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 motorcycle, 12.2ms
# Speed: 2.4ms preprocess, 12.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 motorcycle, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 12.7ms
# Speed: 2.3ms preprocess, 12.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.9ms
# Speed: 2.4ms preprocess, 13.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.6ms
# Speed: 2.4ms preprocess, 13.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.0ms
# Speed: 2.7ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 10.9ms
# Speed: 5.7ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 10.9ms
# Speed: 10.8ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.4ms
# Speed: 2.6ms preprocess, 11.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 motorcycle, 11.0ms
# Speed: 2.3ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Log data saved to: /content/drive/MyDrive/Capstone/Results/02.24 1200-1400/Log data/1330-1400_log.csv
# Interval data saved to: /content/drive/MyDrive/Capstone/Results/02.24 1200-1400/Interval data/1330-1400_interval.csv

# %%
###### Extracting Frames by video ######


import cv2
import os

def extract_frames(video_path, output_dir, frame_interval=1):
    """
    특정 경로의 비디오 파일에서 프레임을 추출하여 지정된 디렉토리에 저장하는 함수.

    :param video_path: 비디오 파일 경로 (예: "input/video.mp4")
    :param output_dir: 프레임이 저장될 디렉토리 경로 (예: "output/frames")
    :param frame_interval: 프레임을 저장할 간격 (1이면 모든 프레임 저장, 2이면 2프레임마다 저장)
    """
    # 출력 디렉토리 생성 (없으면 자동 생성)
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # 비디오 캡처 객체 생성
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print(f"Error: Cannot open video file {video_path}")
        return

    frame_count = 0
    saved_count = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break  # 더 이상 프레임이 없으면 종료

        # 프레임 간격에 따라 저장 (예: 1프레임씩, 2프레임씩 저장 가능)
        if frame_count % frame_interval == 0:
            frame_filename = os.path.join(output_dir, f"frame_{saved_count:04d}.jpg")
            cv2.imwrite(frame_filename, frame)
            saved_count += 1
            print(f"Saved: {frame_filename}")

        frame_count += 1

    cap.release()
    print(f"\n✅ Total {saved_count} frames saved in {output_dir}")

# 사용 예시
video_path = "/content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Log video/04.10 1930-2000_processed_video.avi"  # 입력 비디오 파일 경로
output_dir = "/content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000"  # 저장할 디렉토리
frame_interval = 1  # 모든 프레임 저장 (2이면 2프레임마다 저장)

extract_frames(video_path, output_dir, frame_interval)
# Out:
# Streaming output truncated to the last 5000 lines.
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1545.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1546.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1547.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1548.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1549.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1550.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1551.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1552.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1553.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1554.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1555.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1556.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1557.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1558.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1559.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1560.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1561.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1562.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1563.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1564.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1565.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1566.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1567.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1568.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1569.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1570.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1571.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1572.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1573.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1574.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1575.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1576.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1577.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1578.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1579.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1580.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1581.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1582.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1583.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1584.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1585.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1586.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1587.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1588.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1589.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1590.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1591.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1592.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1593.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1594.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1595.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1596.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1597.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1598.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1599.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1600.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1601.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1602.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1603.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1604.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1605.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1606.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1607.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1608.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1609.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1610.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1611.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1612.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1613.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1614.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1615.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1616.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1617.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1618.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1619.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1620.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1621.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1622.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1623.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1624.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1625.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1626.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1627.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1628.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1629.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1630.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1631.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1632.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1633.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1634.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1635.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1636.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1637.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1638.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1639.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1640.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1641.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1642.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1643.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1644.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1645.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1646.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1647.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1648.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1649.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1650.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1651.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1652.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1653.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1654.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1655.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1656.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1657.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1658.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1659.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1660.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1661.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1662.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1663.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1664.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1665.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1666.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1667.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1668.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1669.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1670.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1671.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1672.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1673.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1674.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1675.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1676.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1677.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1678.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1679.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1680.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1681.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1682.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1683.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1684.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1685.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1686.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1687.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1688.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1689.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1690.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1691.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1692.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1693.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1694.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1695.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1696.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1697.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1698.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1699.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1700.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1701.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1702.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1703.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1704.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1705.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1706.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1707.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1708.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1709.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1710.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1711.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1712.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1713.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1714.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1715.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1716.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1717.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1718.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1719.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1720.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1721.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1722.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1723.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1724.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1725.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1726.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1727.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1728.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1729.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1730.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1731.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1732.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1733.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1734.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1735.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1736.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1737.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1738.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1739.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1740.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1741.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1742.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1743.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1744.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1745.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1746.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1747.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1748.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1749.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1750.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1751.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1752.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1753.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1754.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1755.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1756.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1757.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1758.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1759.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1760.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1761.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1762.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1763.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1764.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1765.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1766.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1767.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1768.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1769.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1770.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1771.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1772.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1773.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1774.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1775.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1776.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1777.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1778.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1779.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1780.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1781.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1782.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1783.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1784.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1785.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1786.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1787.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1788.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1789.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1790.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1791.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1792.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1793.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1794.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1795.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1796.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1797.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1798.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1799.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1800.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1801.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1802.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1803.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1804.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1805.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1806.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1807.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1808.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1809.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1810.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1811.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1812.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1813.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1814.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1815.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1816.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1817.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1818.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1819.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1820.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1821.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1822.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1823.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1824.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1825.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1826.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1827.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1828.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1829.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1830.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1831.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1832.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1833.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1834.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1835.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1836.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1837.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1838.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1839.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1840.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1841.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1842.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1843.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1844.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1845.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1846.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1847.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1848.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1849.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1850.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1851.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1852.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1853.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1854.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1855.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1856.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1857.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1858.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1859.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1860.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1861.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1862.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1863.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1864.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1865.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1866.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1867.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1868.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1869.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1870.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1871.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1872.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1873.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1874.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1875.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1876.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1877.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1878.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1879.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1880.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1881.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1882.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1883.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1884.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1885.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1886.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1887.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1888.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1889.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1890.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1891.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1892.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1893.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1894.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1895.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1896.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1897.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1898.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1899.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1900.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1901.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1902.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1903.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1904.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1905.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1906.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1907.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1908.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1909.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1910.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1911.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1912.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1913.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1914.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1915.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1916.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1917.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1918.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1919.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1920.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1921.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1922.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1923.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1924.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1925.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1926.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1927.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1928.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1929.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1930.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1931.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1932.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1933.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1934.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1935.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1936.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1937.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1938.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1939.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1940.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1941.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1942.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1943.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1944.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1945.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1946.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1947.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1948.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1949.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1950.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1951.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1952.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1953.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1954.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1955.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1956.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1957.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1958.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1959.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1960.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1961.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1962.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1963.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1964.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1965.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1966.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1967.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1968.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1969.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1970.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1971.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1972.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1973.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1974.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1975.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1976.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1977.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1978.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1979.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1980.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1981.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1982.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1983.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1984.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1985.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1986.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1987.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1988.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1989.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1990.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1991.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1992.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1993.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1994.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1995.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1996.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1997.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1998.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_1999.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_2000.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_2001.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_2002.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_2003.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_2004.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_2005.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_2006.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_2007.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_2008.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_2009.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_2010.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_2011.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_2012.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_2013.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_2014.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_2015.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_2016.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_2017.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_2018.jpg
# ...
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6386.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6387.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6388.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6389.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6390.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6391.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6392.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6393.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6394.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6395.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6396.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6397.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6398.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6399.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6400.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6401.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6402.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6403.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6404.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6405.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6406.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6407.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6408.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6409.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6410.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6411.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6412.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6413.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6414.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6415.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6416.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6417.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6418.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6419.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6420.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6421.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6422.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6423.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6424.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6425.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6426.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6427.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6428.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6429.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6430.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6431.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6432.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6433.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6434.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6435.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6436.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6437.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6438.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6439.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6440.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6441.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6442.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6443.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6444.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6445.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6446.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6447.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6448.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6449.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6450.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6451.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6452.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6453.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6454.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6455.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6456.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6457.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6458.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6459.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6460.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6461.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6462.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6463.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6464.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6465.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6466.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6467.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6468.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6469.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6470.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6471.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6472.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6473.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6474.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6475.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6476.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6477.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6478.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6479.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6480.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6481.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6482.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6483.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6484.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6485.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6486.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6487.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6488.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6489.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6490.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6491.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6492.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6493.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6494.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6495.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6496.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6497.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6498.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6499.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6500.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6501.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6502.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6503.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6504.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6505.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6506.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6507.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6508.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6509.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6510.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6511.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6512.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6513.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6514.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6515.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6516.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6517.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6518.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6519.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6520.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6521.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6522.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6523.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6524.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6525.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6526.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6527.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6528.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6529.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6530.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6531.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6532.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6533.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6534.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6535.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6536.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6537.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6538.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6539.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6540.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6541.jpg
# Saved: /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000/frame_6542.jpg
#
# ✅ Total 6543 frames saved in /content/drive/MyDrive/Capstone/Results/04.10 1800-2000/Frames/04.10 1930-2000
